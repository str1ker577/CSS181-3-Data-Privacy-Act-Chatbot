# %% [markdown]
# # ***Tenno: Data Privacy Act***

# %% [markdown]
# ## **Falcon-7B Baseline Evaluation**

# %% [markdown]
# This notebook evaluates Falcon-7B under a Retrieval-Augmented Generation (RAG) setup. For each frozen baseline prompt, the system retrieves the top-k most relevant legal chunks from the prebuilt FAISS index and supplies them as context to the model. The model then generates an answer grounded in retrieved text.

# %% [markdown]
# All outputs are saved to Google Drive in JSON format for later aggregation and metric computation (Exact Match, ROUGE-L, Faithfulness, Recall@k).

# %% [markdown]
# ## **Install Required Packages**
#
# ---

# %%
# !pip install -q transformers accelerate bitsandbytes faiss-cpu sentence-transformers tqdm

# %% [markdown]
# This installs the libraries required to load Falcon-7B, load the saved FAISS index, retrieve relevant chunks, and run inference in Colab.

# %% [markdown]
# ## **Mount Drive**
#
# ---

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Mounts Google Drive so the notebook can read the frozen prompts and FAISS retrieval artifacts and save model outputs back to Drive

# %% [markdown]
# ## **Persistent Hugging Face CachePersistent Hugging Face Cache**
#
# ---

# %%
import os

PROJECT_DIR = "/content/drive/MyDrive/Mapua /3rd Year Term 2/CSS181-3/NLP_Project"
HF_CACHE_DIR = f"{PROJECT_DIR}/Models/hf_cache"  # persistent cache in Drive

os.makedirs(HF_CACHE_DIR, exist_ok=True)

# Force HF/Transformers to use Drive cache
os.environ["HF_HOME"] = HF_CACHE_DIR
os.environ["HUGGINGFACE_HUB_CACHE"] = HF_CACHE_DIR
os.environ["TRANSFORMERS_CACHE"] = HF_CACHE_DIR

print("✅ Using persistent HF cache:", HF_CACHE_DIR)
# Out:
# ✅ Using persistent HF cache: /content/drive/MyDrive/Mapua /3rd Year Term 2/CSS181-3/NLP_Project/Models/hf_cache

# %% [markdown]
# This ensures model downloads are cached in Google Drive so you don’t re-download weights every session.

# %% [markdown]
# ## **Define Paths + Load Prompts and FAISS Artifacts**
#
# ---

# %%
import os, json
import faiss

PROJECT_DIR = "/content/drive/MyDrive/Mapua /3rd Year Term 2/CSS181-3/NLP_Project"

PROMPTS_FILE = f"{PROJECT_DIR}/Prompts/baseline_prompts_v1.json"
FAISS_INDEX_PATH = f"{PROJECT_DIR}/Chunks/faiss_index.bin"
FAISS_META_PATH = f"{PROJECT_DIR}/Chunks/faiss_metadata.json"

RESULTS_DIR = f"{PROJECT_DIR}/Results"
os.makedirs(RESULTS_DIR, exist_ok=True)

OUTPUT_PATH = f"{RESULTS_DIR}/baseline_outputs_falcon.json"

# Load prompts
with open(PROMPTS_FILE, "r", encoding="utf-8") as f:
    prompts = json.load(f)

# Load FAISS index
index = faiss.read_index(FAISS_INDEX_PATH)

# Load metadata (must align with index vector order)
with open(FAISS_META_PATH, "r", encoding="utf-8") as f:
    meta = json.load(f)

print("✅ Prompts loaded:", len(prompts))
print("✅ FAISS vectors:", index.ntotal)
print("✅ Metadata rows:", len(meta))
# Out:
# ✅ Prompts loaded: 10
# ✅ FAISS vectors: 198
# ✅ Metadata rows: 198

# %% [markdown]
# This loads the frozen prompt list, the saved FAISS vector index, and the metadata mapping from vector IDs back to chunk text and source information. These three components form the retrieval backbone of the RAG evaluation.

# %% [markdown]
# ## **Load SentenceTransformer for Query Embedding**
#
# ---

# %%
from sentence_transformers import SentenceTransformer

embed_model_name = "all-MiniLM-L6-v2"
embedder = SentenceTransformer(embed_model_name)

print(f"✅ Query embedder loaded: {embed_model_name}")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# ✅ Query embedder loaded: all-MiniLM-L6-v2

# %% [markdown]
# FAISS retrieval requires embedding the user query (the prompt question) into a vector. We reuse the same embedding model used to build the FAISS index to ensure compatible vector representations.

# %% [markdown]
# ## **Retrieval Helper (Top-k Chunks)**
#
# ---

# %%
import numpy as np

TOP_K = 3

def retrieve_top_k_chunks(query: str, top_k: int = TOP_K):
    q_emb = embedder.encode([query], convert_to_numpy=True)
    q_emb = q_emb.astype(np.float32)

    distances, indices = index.search(q_emb, top_k)
    idxs = indices[0].tolist()

    retrieved = []
    for i in idxs:
        row = meta[i]
        retrieved.append({
            "faiss_id": i,
            "text": row.get("text", ""),
            "source": row.get("source", ""),
            "page_number": row.get("page_number", None),
            "distance": float(distances[0][idxs.index(i)])
        })
    return retrieved

# %% [markdown]
# This function embeds the prompt question, retrieves the top-k closest chunk vectors from FAISS, and returns the corresponding chunk text and metadata. This is the “dictionary skimming” step in your analogy.

# %% [markdown]
# ## **Load Falcon-7B Model (4-bit)**
#
# ---

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM, BitsAndBytesConfig

MODEL_ID = "tiiuae/falcon-7b-instruct"

bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_compute_dtype=torch.float16,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
)

print("Loading Falcon tokenizer...")
tokenizer = AutoTokenizer.from_pretrained(MODEL_ID, cache_dir=HF_CACHE_DIR)

if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token

print("Loading Falcon model (4-bit)...")
model = AutoModelForCausalLM.from_pretrained(
    MODEL_ID,
    cache_dir=HF_CACHE_DIR,
    device_map="auto",
    quantization_config=bnb_config,
)

model.eval()
print("✅ Falcon loaded in 4-bit.")
# Out:
# Loading Falcon tokenizer...
# Loading Falcon model (4-bit)...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie transformer.word_embeddings.weight to lm_head.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# generation_config.json:   0%|          | 0.00/117 [00:00<?, ?B/s]
# ✅ Falcon loaded in 4-bit.

# %% [markdown]
# This loads Falcon-7B-Instruct using Hugging Face Transformers. device_map="auto" places the model on available GPU resources. The model will generate answers using retrieved legal context.

# %% [markdown]
# ## **Build Model Input (Context + Question)**
#
# ---

# %%
def build_rag_input(retrieved_chunks, question: str) -> str:
    context_blocks = []
    for c in retrieved_chunks:
        src = c["source"]
        pg = c["page_number"]
        txt = c["text"]
        context_blocks.append(f"[Source: {src} | Page: {pg}]\n{txt}")

    context = "\n\n---\n\n".join(context_blocks)

    return (
        "You are a legal assistant. Answer the question using ONLY the retrieved context.\n\n"
        f"Retrieved Context (Top-{TOP_K}):\n{context}\n\n"
        f"Question:\n{question}\n\n"
        "Answer:"
    )

# %% [markdown]
# ## **Deterministic Generation Helper**
#
# ---

# %%
@torch.inference_mode()
def generate_answer(input_text: str, max_new_tokens: int = 256) -> str:
    inputs = tokenizer(input_text, return_tensors="pt").to(model.device)

    out_ids = model.generate(
        **inputs,
        do_sample=False,
        temperature=0.0,
        top_p=1.0,
        max_new_tokens=max_new_tokens,
        pad_token_id=tokenizer.eos_token_id
    )

    decoded = tokenizer.decode(out_ids[0], skip_special_tokens=True)
    return decoded[len(input_text):].strip()

# %% [markdown]
# This generates answers using deterministic decoding (temperature=0, do_sample=False) to ensure reproducibility across runs. The function returns only the generated portion of the output.

# %% [markdown]
# ## **Run All Prompts and Save Outputs**
#
# ---

# %%
from tqdm import tqdm
import time

results = []

for p in tqdm(prompts, desc="Running Falcon RAG prompts"):
    q = p["question"]

    retrieved = retrieve_top_k_chunks(q, top_k=TOP_K)
    input_text = build_rag_input(retrieved, q)

    answer = generate_answer(input_text, max_new_tokens=256)

    results.append({
        "model_id": MODEL_ID,
        "prompt_id": p.get("prompt_id"),
        "title": p.get("title"),
        "method": p.get("method"),
        "condition": p.get("condition"),
        "dataset_file": p.get("dataset_file"),
        "section_index": p.get("section_index"),
        "question": q,
        "retrieved_chunks": retrieved,
        "answer": answer,
        "expected_output": p.get("expected_output")
    })

# Save
with open(OUTPUT_PATH, "w", encoding="utf-8") as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print("✅ Saved outputs to:", OUTPUT_PATH)
# Out:
# Running Falcon RAG prompts:   0%|          | 0/10 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['temperature']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Running Falcon RAG prompts: 100%|██████████| 10/10 [02:32<00:00, 15.27s/it]
# ✅ Saved outputs to: /content/drive/MyDrive/Mapua /3rd Year Term 2/CSS181-3/NLP_Project/Results/baseline_outputs_falcon.json

# %% [markdown]
# This loop runs all baseline prompts through the full RAG pipeline: query embedding → FAISS retrieval → context construction → Falcon generation. Outputs are saved to a JSON file containing both retrieved evidence and generated responses for later scoring.

# %% [markdown]
# ## **Display Outputs**
#
# ---

# %%
from pprint import pprint

RESULTS_PATH = f"{PROJECT_DIR}/Results/baseline_outputs_falcon.json"

# Load results
with open(RESULTS_PATH, "r", encoding="utf-8") as f:
    results = json.load(f)

print(f"\n✅ Loaded {len(results)} Falcon outputs\n")

# Display brief preview
for item in results:
    print("=" * 80)
    print(f"[Prompt {item['prompt_id']}] ({item['method']})")
    print("-" * 80)
    print("Q:", item["question"])
    print("\nA:", item["answer"][:400])
    print("\n")
# Out:
# ✅ Loaded 10 Falcon outputs
#
# ================================================================================
# [Prompt 1] (Zero-Shot)
# --------------------------------------------------------------------------------
# Q: List all the conditions under which the processing of personal information is considered lawful according to this section.
#
# A: The processing of personal information is considered lawful according to this section if it is:
#
# 1. For the purpose of entering into a contract with the data subject.
# 2. For the purpose of taking steps at the request of the data subject prior to entering into a contract.
# 3. For the purpose of complying with a legal obligation to which the personal information controller is subject.
# 4. For the purp
#
#
# ================================================================================
# [Prompt 2] (Zero-Shot)
# --------------------------------------------------------------------------------
# Q: What are the penalties for unauthorized disclosure of personal information and sensitive personal information under this section?
#
# A: The penalties for unauthorized disclosure of personal information and sensitive personal information under this section are imprisonment ranging from one (1) year to three (3) years and a fine of not less than five hundred thousand pesos (php500,000.00) but not more than one million pesos (php1,000,000.00).
#
#
# ================================================================================
# [Prompt 3] (Chain-of-Thought Prompting)
# --------------------------------------------------------------------------------
# Q: Based on the legal definition, list what qualifies as sensitive personal information and briefly explain why each qualifies.
#
# A: 1. Race, ethnic origin, marital status, age, color, and religious, philosophical or political affiliations: These are personal information that are considered sensitive because they are often used to identify a person and can be used to discriminate against them.
#
# 2. Health, education, genetic or sexual life of an individual: These are personal information that are considered sensitive because the
#
#
# ================================================================================
# [Prompt 4] (Chain-of-Thought Prompting)
# --------------------------------------------------------------------------------
# Q: Explain the general data privacy principles outlined in this section and why each principle is important.
#
# A: The general data privacy principles outlined in this section are:
#
# 1. Data security: This principle ensures that personal data is stored securely and protected from unauthorized access, use, or disclosure.
#
# 2. Data accuracy: This principle ensures that personal data is accurate, complete, and up-to-date.
#
# 3. Data retention: This principle ensures that personal data is not stored for longer than ne
#
#
# ================================================================================
# [Prompt 5] (One-Shot Learning Prompt)
# --------------------------------------------------------------------------------
# Q: List the rights granted to data subjects under this section.
#
# A: The rights granted to data subjects under this section are:
#
# 1. Right to access personal data
# 2. Right to data portability
# 3. Right to be informed
# 4. Right to rectification
# 5. Right to erasure
# 6. Right to restriction of processing
# 7. Right to object to processing
# 8. Right to data portability
# 9. Right to withdraw consent
# 10. Right to be forgotten
# 11. Right to be informed of a data breach
# 12. Right
#
#
# ================================================================================
# [Prompt 6] (One-Shot Learning Prompt)
# --------------------------------------------------------------------------------
# Q: Summarize the breach notification requirement.
#
# A: The breach notification requirement is that a personal information controller must notify the National Privacy Commission (NPC) of any security breach or personal data breach that may have occurred. The notification must include the type of breach, the personal data that was affected, the date of the breach, and the contact information of the person responsible for the breach. The notification mus
#
#
# ================================================================================
# [Prompt 7] (One-Shot Learning Prompt)
# --------------------------------------------------------------------------------
# Q: Explain what the principle of proportionality means.
#
# A: The principle of proportionality means that the amount of personal data collected and processed should be in proportion to the purpose for which it is being collected and processed. In other words, the amount of personal data collected and processed should be in proportion to the legitimate purpose of the collection and processing.
#
#
# ================================================================================
# [Prompt 8] (One-Shot Learning Prompt)
# --------------------------------------------------------------------------------
# Q: List the three types of security measures required.
#
# A: 1. Physical security measures
# 2. Data security measures
# 3. Network security measures
#
#
# ================================================================================
# [Prompt 9] (Negative Prompting)
# --------------------------------------------------------------------------------
# Q: List only the lawful processing conditions mentioned.
#
# A: 1. Consent of the data subject
# 2. Processing is necessary for the performance of a contract
# 3. Processing is necessary for the exercise of a public function
# 4. Processing is necessary for the purpose of scientific or historical research
# 5. Processing is necessary for the purpose of statistical or research
# 6. Processing is necessary for the purpose of preventing or investigating a crime
# 7. Processi
#
#
# ================================================================================
# [Prompt 10] (Negative Prompting)
# --------------------------------------------------------------------------------
# Q: Identify the penalties for unauthorized disclosure.
#
# A: The penalties for unauthorized disclosure are imprisonment ranging from one (1) year to three (3) years and a fine of not less than five hundred thousand pesos (php500,000.00) but not more than one million pesos (php1,000,000.00).

# %% [markdown]
# This prints a compact preview of each generated answer to verify the notebook produced reasonable outputs before moving to the next model.
